# %%
import torch
from torch import nn
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook
from copy import deepcopy

# %%
from model import AudioCNN

# %%
checkpoint_path = 'model_checkpoints/edm_genre_epoch_22_acc_0.9480_vs_0.7909_loss_5.4965_vs_6.3733.pth'
checkpoint_path = 'model_checkpoints/edm_genre_epoch_61_acc_0.9919_vs_0.7955_loss_3.2539_vs_4.3752.pth'
checkpoint_path = 'model_checkpoints/edm_genre_epoch_59_acc_0.8197_vs_0.7273_loss_1.8854_vs_2.2722.pth'
checkpoint_path = 'model_checkpoints/edm_genre_epoch_79_acc_0.9379_vs_0.7045_loss_1.4581_vs_2.2103.pth'
checkpoint_path = 'model_checkpoints/edm_genre_epoch_16_acc_0.9232_vs_0.8455_loss_6.3483_vs_6.8122.pth'

checkpoint = torch.load(checkpoint_path)
model = AudioCNN()
model.load_state_dict(checkpoint)
model.eval();

embedder = deepcopy(model)
embedder.model.fc = nn.Sequential()
embedder.eval();

# %%
idxs_path = 'valid_index.json'
with open(idxs_path, 'r') as file:
    valid_idxs = file.read().split('\n')[:-1]
    valid_idxs = [int(x) for x in valid_idxs]
    
class_map_path = 'class_map.json'
with open(class_map_path, 'r') as file:
    class_map = file.read().split('\n')[:-1]

# %%
import torchvision.transforms as T

data = np.load('/root/konst/melspects_general.npz', mmap_mode='r', allow_pickle=True)

transform = T.Compose([
    #T.ToTensor(),
    T.Lambda(lambda x: torch.FloatTensor(x / 255.0)),
])

labels = []
preds = []
filenames = []
embeds = []
for idx in tqdm_notebook(valid_idxs):
    img = data['x'][idx]
    label = data['y'][idx]
    label = class_map.index(label)
    img = transform(img)
    img = img.unsqueeze(0)
    output = model(img)
    _, pred = torch.max(output, 1)
    labels.append(label)
    preds.append(int(pred))
    filenames.append(data['filenames'][idx])
    
    embed = embedder(img)
    embeds.append(embed)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/220 [00:00<?, ?it/s]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print(class_map)
print('Acc: ', accuracy_score(labels, preds))
confusion_matrix(labels, preds)
# Out:
# ['House', 'Trap', 'Trance']
# Acc:  0.8454545454545455
# array([[135,   9,   7],
#        [  9,  27,   1],
#        [  7,   1,  24]])

# %%
df = pd.DataFrame(zip(labels, preds, filenames), columns=['label', 'pred', 'filename'])
df['label'] = df.label.apply(lambda x: class_map[x])
df['pred'] = df.pred.apply(lambda x: class_map[x])

# %%
(3 * 60 + 42) * 0.7
# Out:
# 155.39999999999998

# %%
df[(df.label == 'House') & (df.pred == 'Trap')]
# Out:
#      label  pred                                           filename  \
# 39   House  Trap  Bodybangers Feat. Victoria Ker - -  Stars In M...
# 68   House  Trap  Lutez_Smash (Original Mix) [DutchHM] [2017] [v...
# 70   House  Trap  Gama_KillKid_Tribu_Otiginal_Mix_(vmuzice.com).mp3
# 74   House  Trap                 Zendex - Diablo (Original Mix).mp3
# 77   House  Trap  PERCY_-HARD_PEACE__KOE_2016___https___vk.com_k...
# 81   House  Trap                     Zendex - Asylum (Club Mix).mp3
# 92   House  Trap                   Tiesto & MOTi-Blow Your Mind.mp3
# 152  House  Trap  R3hab David Solano - Do It (Life In Color Anth...
# 185  House  Trap               Pegboard Nerds - Melodymania VIP.mp3
#
#           delta
# 39   128.947647
# 68    91.678131
# 70   154.827148
# 74   102.844803
# 77   122.446426
# 81   211.054550
# 92   146.606934
# 152   84.545845
# 185  123.706200

# %%
# ArcFace

# %%
embedder(torch.randn(1, 2, 10, 10)).shape
# Out:
# torch.Size([1, 1024])

# %%
from pytorch_metric_learning.losses import ArcFaceLoss

loss_func = ArcFaceLoss(num_classes=3, embedding_size=1024, margin=28.6, scale=64)
loss_func(torch.randn(2, 100), torch.LongTensor([0, 1]))
loss_func
# Out:
# ArcFaceLoss(
#   (distance): CosineSimilarity()
#   (reducer): MeanReducer()
#   (cross_entropy): CrossEntropyLoss()
# )

# %%
from scipy.spatial.distance import cosine
filename = 'Skrillex & Diplo & Snails - Holla Out (feat  Taranchyla).mp3'
#filename = 'Twoloud  -  Big Bang (Original Mix).mp3'
#filename = 'Hardwell-Encoded (Radio Edit).mp3'
filename = 'Sunny_Lax_-_So_Long (www.mp3zv.me).mp3'
#filename = 'Greg House & Golden Fingers - Weekend Bangers (Radio Edit).mp3'

def rel_metric(arr1, arr2):
    arr1 = list(arr1[0])
    arr2 = list(arr2[0])
    return sum([((a1 - a2) / max(a1, a2))**2 if max(a1, a2) > 0 else 0 for a1, a2 in zip(arr1, arr2)])

embed = embeds[filenames.index(filename)]
deltas = [cosine(embed.detach().numpy(), e.detach().numpy()) for e in embeds]
#deltas = [float((embed - e).abs().sum()) for e in embeds]
#deltas = [rel_metric(embed.detach().numpy(), e.detach().numpy()) for e in embeds]

df['delta'] = deltas
df.sort_values('delta')[:30]
# Out:
#       label    pred                                           filename  \
# 207  Trance  Trance             Sunny_Lax_-_So_Long (www.mp3zv.me).mp3
# 203  Trance  Trance        Sunny_Lax_-_Adapt_Or_Die (www.mp3zv.me).mp3
# 196  Trance  Trance   audien_-_hindsight_original_mix_(zaycev.net).mp3
# 211  Trance  Trance        Cosmic_Gate_Super8_Tab_-_Noom_Album_Mix.mp3
# 216  Trance  Trance                          Farius_-_Echo_Chamber.mp3
# 205  Trance  Trance  cressida_-_6_am_kyau_and_albert_remix_(zaycev....
# 188  Trance  Trance  dns_project_feat._madelin_zero_-_another_day_o...
# 190  Trance  Trance  Mysterious_Movement_-_On_The_Edge_Original_Mix...
# 210  Trance  Trance  Sunny_Lax_-_Bad_Bye_Extended_Mix (www.mp3zv.me...
# 195  Trance  Trance                    ben-gold-omnia-the-conquest.mp3
# 193  Trance  Trance     Protoculture_Johnny_Yono_Luna_(xgetmus.ru).mp3
# 191  Trance  Trance  muzmo_ru_Arty_-_Last_Kiss_Original_Mix_6255676...
# 219  Trance  Trance  muzmo_ru_Evgeny_Lebedev_-_Sun_in_Your_Eyes_542...
# 206  Trance  Trance         Super8 & Tab_Into_2000329694_456240264.mp3
# 215  Trance  Trance       muzlome_Gareth_Emery_-_Gunshots_69985227.mp3
# 27     Trap  Trance         GTA & Valentino Khan - Break Your Neck.mp3
# 202  Trance  Trance  Grum_Something About You (Original Mix)_200026...
# 197  Trance  Trance          salt-tank-eugina-ciaran-mcauley-remix.mp3
# 214  Trance  Trance            Super8___Tab-Teardrops__Radio_Edit_.mp3
# 218  Trance  Trance  muzlome_Luke_Bond_-_Before_The_Story_50750462.mp3
# 121   House  Trance  06_dash_berlin_coming_home_feat_bo_bruce_myzuk...
# 198  Trance  Trance  signum-coming-on-strong-gareth-emery-amp-ashle...
# 154   House  Trance  r3hab-nervo-ummet-ozcan-revolution-ncode-remix...
# 140   House   House  Dimitri Vegas & Like Mike, Steve Aoki ♫ - We A...
# 194  Trance  Trance       Tom_Staar_feat_Matt_Hope_-_Come_Together.mp3
# 189  Trance  Trance  ilan Bluestone – Rival (ft. Ellen Smith) (Rafa...
# 200  Trance  Trance      Cosmic_Gate_-_Falling_Back (www.mp3zv.me).mp3
# 87    House  Trance  kshmr-feat.-jdg-mariana-bo-kolkata-original-mi...
# 163   House   House  muzlome_Julian_Jordan_-_Blinded_By_The_Light_O...
# 63    House  Trance         Royal_Brothers-ILLUSION__Original_Mix_.mp3
#
#         delta
# 207  0.000000
# 203  0.004402
# 196  0.004579
# 211  0.004782
# 216  0.005563
# 205  0.006088
# 188  0.007417
# 190  0.008173
# 210  0.008216
# 195  0.008644
# 193  0.010273
# 191  0.011017
# 219  0.011897
# 206  0.014503
# 215  0.016922
# 27   0.017331
# 202  0.025795
# 197  0.029961
# 214  0.044818
# 218  0.052610
# 121  0.053467
# 198  0.054740
# 154  0.068894
# 140  0.070481
# 194  0.079585
# 189  0.079624
# 200  0.090468
# 87   0.094676
# 163  0.097999
# 63   0.103351
